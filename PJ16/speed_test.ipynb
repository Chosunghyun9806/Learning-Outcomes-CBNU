# %%
from ultralytics import YOLO

# %%
data_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\데이터\속도테스트용\data'

# %%
# yolov9c_aug model
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\detect\yolov9c_aug\train2\weights\best.pt'
model = YOLO(model_dir)
result = model(data_dir, save=True, show_labels=False, show_conf=False)
# Out:
# image 1/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061285.jpg: 480x640 16 {0: 'brearing'}s, 19.5ms
# image 2/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061436.jpg: 480x640 20 {0: 'brearing'}s, 20.9ms
# image 3/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061457.jpg: 480x640 4 {0: 'brearing'}s, 20.6ms
# image 4/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061898.jpg: 480x640 9 {0: 'brearing'}s, 19.8ms
# image 5/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062506.jpg: 480x640 6 {0: 'brearing'}s, 19.1ms
# image 6/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062507.jpg: 480x640 5 {0: 'brearing'}s, 17.0ms
# image 7/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062509.jpg: 480x640 5 {0: 'brearing'}s, 18.9ms
# image 8/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062651.jpg: 480x640 28 {0: 'brearing'}s, 18.5ms
# ...

# %%
# yolov9c_aug2 model
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\detect\yolov9c_aug2\train\weights\best.pt'
model = YOLO(model_dir)
result = model(data_dir, save=True,  show_labels=False, show_conf=False)
# Out:
# image 1/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061285.jpg: 480x640 16 {0: 'brearing'}s, 18.8ms
# image 2/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061436.jpg: 480x640 20 {0: 'brearing'}s, 19.9ms
# image 3/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061457.jpg: 480x640 4 {0: 'brearing'}s, 19.7ms
# image 4/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061898.jpg: 480x640 9 {0: 'brearing'}s, 21.1ms
# image 5/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062506.jpg: 480x640 6 {0: 'brearing'}s, 20.8ms
# image 6/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062507.jpg: 480x640 5 {0: 'brearing'}s, 19.2ms
# image 7/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062509.jpg: 480x640 5 {0: 'brearing'}s, 18.2ms
# image 8/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062651.jpg: 480x640 28 {0: 'brearing'}s, 17.7ms
# ...

# %%
# yolov10l_aug model
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\detect\yolov10l_aug\train4\weights\best.pt'
model = YOLO(model_dir)
result = model(data_dir, save=True,  show_labels=False, show_conf=False)
# Out:
# image 1/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061285.jpg: 480x640 16 {0: 'brearing'}s, 17.3ms
# image 2/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061436.jpg: 480x640 20 {0: 'brearing'}s, 18.5ms
# image 3/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061457.jpg: 480x640 4 {0: 'brearing'}s, 17.1ms
# image 4/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061898.jpg: 480x640 9 {0: 'brearing'}s, 17.6ms
# image 5/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062506.jpg: 480x640 6 {0: 'brearing'}s, 17.6ms
# image 6/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062507.jpg: 480x640 5 {0: 'brearing'}s, 17.1ms
# image 7/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062509.jpg: 480x640 5 {0: 'brearing'}s, 24.8ms
# image 8/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062651.jpg: 480x640 28 {0: 'brearing'}s, 17.6ms
# ...

# %%
# yolov10x_aug model
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\detect\yolov10x_aug\train4\weights\best.pt'
model = YOLO(model_dir)
result = model(data_dir, save=True,  show_labels=False, show_conf=False)
# Out:
# image 1/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061285.jpg: 480x640 16 {0: 'brearing'}s, 30.6ms
# image 2/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061436.jpg: 480x640 20 {0: 'brearing'}s, 31.3ms
# image 3/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061457.jpg: 480x640 4 {0: 'brearing'}s, 27.1ms
# image 4/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0061898.jpg: 480x640 9 {0: 'brearing'}s, 24.6ms
# image 5/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062506.jpg: 480x640 6 {0: 'brearing'}s, 23.8ms
# image 6/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062507.jpg: 480x640 5 {0: 'brearing'}s, 26.1ms
# image 7/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062509.jpg: 480x640 5 {0: 'brearing'}s, 23.2ms
# image 8/105 C:\Users\ghkdr\Desktop\\\\\\data\batch_106_save_images_0062651.jpg: 480x640 28 {0: 'brearing'}s, 23.5ms
# ...

# %%
yaml_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\데이터\CH03_data2\train_data\data.yaml'

# %%
# yolov9c_aug model
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\detect\yolov9c_aug\train2\weights\best.pt'
model = YOLO(model_dir)
validation_results = model.val(data=yaml_dir, batch=32, conf=0.8, iou=0.6, save=True)
# Out:
# Ultralytics YOLOv8.2.100  Python-3.8.19 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLOv9c summary (fused): 384 layers, 25,320,019 parameters, 0 gradients, 102.3 GFLOPs
# val: Scanning C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\데이터\CH03_data2\train_data\data\test\labels.cache... 774 im
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 28/28 [00:18
#                    all        877       3135      0.999      0.951      0.975      0.948
# Speed: 0.4ms preprocess, 14.3ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs\detect\val

# %%
# yolov9c_aug2 model
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\detect\yolov9c_aug2\train\weights\best.pt'
model = YOLO(model_dir)
validation_results = model.val(data=yaml_dir, batch=32, conf=0.8, iou=0.6, save=True)
# Out:
# Ultralytics YOLOv8.2.100  Python-3.8.19 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLOv9c summary (fused): 384 layers, 25,320,019 parameters, 0 gradients, 102.3 GFLOPs
# val: Scanning C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\데이터\CH03_data2\train_data\data\test\labels.cache... 774 im
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 28/28 [00:18
#                    all        877       3135      0.998       0.95      0.974      0.945
# Speed: 0.4ms preprocess, 14.6ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs\detect\val3

# %%
# yolov10l_aug model
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\detect\yolov10l_aug\train4\weights\best.pt'
model = YOLO(model_dir)
validation_results = model.val(data=yaml_dir, batch=32, conf=0.8, iou=0.6, save=True)
# Out:
# Ultralytics YOLOv8.2.100  Python-3.8.19 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLOv10l summary (fused): 461 layers, 25,717,910 parameters, 0 gradients, 126.3 GFLOPs
# val: Scanning C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\데이터\CH03_data2\train_data\data\test\labels.cache... 774 im
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 28/28 [00:20
#                    all        877       3135      0.997      0.974      0.987      0.952
# Speed: 0.3ms preprocess, 17.1ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs\detect\val4

# %%
# yolov10x_aug model
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\best.pt'
model = YOLO(model_dir)
validation_results = model.val(data=yaml_dir, batch=32, conf=0.8, iou=0.6, save=True)
# Out:
# Ultralytics YOLOv8.2.100  Python-3.8.19 torch-2.4.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLOv10l summary (fused): 461 layers, 25,717,910 parameters, 0 gradients, 126.3 GFLOPs
# val: Scanning C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\데이터\CH03_data2\train_data\data\test\labels.cache... 774 im
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 28/28 [00:27
#                    all        877       3135      0.997      0.965      0.982      0.948
# Speed: 0.4ms preprocess, 25.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs\detect\val6

# %%
data_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\데이터\혼합검증용\data\혼합'
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\best.pt'
model = YOLO(model_dir)
result = model(data_dir, save=True,  show_labels=False, show_conf=False)
# Out:
# image 1/100 C:\Users\ghkdr\Desktop\\\\\\data\\batch_51_save_images_0341524.jpg: 480x640 28 {0: 'brearing'}s, 30.5ms
# image 2/100 C:\Users\ghkdr\Desktop\\\\\\data\\new_save_images_0001581.jpg: 480x640 4 {0: 'brearing'}s, 28.1ms
# image 3/100 C:\Users\ghkdr\Desktop\\\\\\data\\new_save_images_0001582.jpg: 480x640 3 {0: 'brearing'}s, 23.0ms
# image 4/100 C:\Users\ghkdr\Desktop\\\\\\data\\new_save_images_0001600.jpg: 480x640 6 {0: 'brearing'}s, 44.6ms
# image 5/100 C:\Users\ghkdr\Desktop\\\\\\data\\new_save_images_0001601.jpg: 480x640 2 {0: 'brearing'}s, 64.5ms
# image 6/100 C:\Users\ghkdr\Desktop\\\\\\data\\new_save_images_0001604.jpg: 480x640 2 {0: 'brearing'}s, 43.6ms
# image 7/100 C:\Users\ghkdr\Desktop\\\\\\data\\new_save_images_0001606.jpg: 480x640 9 {0: 'brearing'}s, 36.2ms
# image 8/100 C:\Users\ghkdr\Desktop\\\\\\data\\new_save_images_0001616.jpg: 480x640 4 {0: 'brearing'}s, 52.7ms
# ...

# %%
model_dir = r'C:\Users\ghkdr\Desktop\성현폴더\충북대\논문\실험\runs\detect\yolov9c_aug\train2\weights\best.pt'
model = YOLO(model_dir)
validation_results = model.val(data=yaml_dir, batch=32, conf=0.6, iou=0.6, save=True)
