# %%
import os
import shutil
import cv2
import numpy as np

from skimage.metrics import structural_similarity as ssim
from skimage.color import rgb2gray

# %%
def move_images(src_folder, dest_folder, batch_size=10):
    # 소스 폴더의 이미지 파일 리스트를 가져옵니다.
    images = [f for f in os.listdir(src_folder) if f.lower().endswith('.jpg')]
    images.sort()  # 이미지 파일명을 정렬하여 순서대로 처리합니다.

    # 이미지 파일을 배치로 나누어 이동합니다.
    for i in range(0, len(images), batch_size):
        batch = images[i:i + batch_size]
        
        # 새로운 디렉토리 이름을 생성합니다.
        batch_folder = os.path.join(dest_folder, f'batch_{i // batch_size + 1}')
        os.makedirs(batch_folder, exist_ok=True)
        
        # 배치에 있는 이미지를 새로운 디렉토리로 이동합니다.
        for image in batch:
            src_path = os.path.join(src_folder, image)
            dest_path = os.path.join(batch_folder, image)
            shutil.move(src_path, dest_path)
            # print(f'Moved: {src_path} -> {dest_path}')

        print(f"batch {i} complete")

# 예제 사용법
src_folder = 'D:/nsk/data/CH03/backup_20240906/NSKTRB/04.images'  # 소스 폴더 경로
dest_folder = 'D:/nsk/data/CH03_output'  # 대상 폴더 경로

# 이동 작업 수행
move_images(src_folder, dest_folder, batch_size=5000)
# Out:
# batch 0 complete
# batch 5000 complete
# batch 10000 complete
# batch 15000 complete
# batch 20000 complete
# batch 25000 complete
# batch 30000 complete
# batch 35000 complete
# batch 40000 complete
# batch 45000 complete
# batch 50000 complete
# batch 55000 complete
# batch 60000 complete
# batch 65000 complete
# batch 70000 complete
# batch 75000 complete
# batch 80000 complete
# batch 85000 complete
# batch 90000 complete
# batch 95000 complete
# batch 100000 complete
# batch 105000 complete
# batch 110000 complete
# batch 115000 complete
# batch 120000 complete
# batch 125000 complete
# batch 130000 complete
# batch 135000 complete
# batch 140000 complete
# batch 145000 complete
# batch 150000 complete
# batch 155000 complete
# batch 160000 complete
# batch 165000 complete
# batch 170000 complete
# batch 175000 complete
# batch 180000 complete
# batch 185000 complete
# batch 190000 complete
# batch 195000 complete
# batch 200000 complete
# batch 205000 complete
# batch 210000 complete
# batch 215000 complete
# batch 220000 complete
# batch 225000 complete
# batch 230000 complete
# batch 235000 complete
# batch 240000 complete
# batch 245000 complete
# batch 250000 complete
# batch 255000 complete
# batch 260000 complete
# batch 265000 complete
# batch 270000 complete
# batch 275000 complete
# batch 280000 complete
# batch 285000 complete
# batch 290000 complete
# batch 295000 complete
# batch 300000 complete
# batch 305000 complete
# batch 310000 complete
# batch 315000 complete
# batch 320000 complete
# batch 325000 complete
# batch 330000 complete
# batch 335000 complete
# batch 340000 complete
# batch 345000 complete
# batch 350000 complete
# batch 355000 complete
# batch 360000 complete
# batch 365000 complete
# batch 370000 complete
# batch 375000 complete
# batch 380000 complete
# batch 385000 complete
# batch 390000 complete
# batch 395000 complete
# batch 400000 complete
# batch 405000 complete
# batch 410000 complete
# batch 415000 complete
# batch 420000 complete
# batch 425000 complete
# batch 430000 complete
# batch 435000 complete
# batch 440000 complete
# batch 445000 complete
# batch 450000 complete
# batch 455000 complete
# batch 460000 complete
# batch 465000 complete
# batch 470000 complete
# batch 475000 complete
# batch 480000 complete
# batch 485000 complete
# batch 490000 complete
# batch 495000 complete
# batch 500000 complete
# batch 505000 complete
# batch 510000 complete
# batch 515000 complete
# batch 520000 complete
# batch 525000 complete
# batch 530000 complete
# batch 535000 complete
# batch 540000 complete
# batch 545000 complete
# batch 550000 complete
# batch 555000 complete
# batch 560000 complete
# batch 565000 complete
# batch 570000 complete

# %%
def compute_image_ssim(image_path1, image_path2):
    """두 이미지 간의 SSIM 값을 계산합니다."""
    img1 = cv2.imread(image_path1)
    img2 = cv2.imread(image_path2)

    # 이미지를 그레이스케일로 변환합니다.
    img1_gray = rgb2gray(img1)
    img2_gray = rgb2gray(img2)

    # 데이터 범위를 설정합니다. (0-255 for uint8 images)
    data_range = img1_gray.max() - img1_gray.min()

    # SSIM 값을 계산합니다.
    score, _ = ssim(img1_gray, img2_gray, data_range=data_range, full=True)
    # print(f"{image_path1} : {image_path2} score : {score}")
    return score

def find_and_remove_duplicates_in_folder(folder_path, threshold=0.8):
    """폴더 내에서 유사한 이미지를 찾아 제거합니다."""
    files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    files.sort() # 파일 이름 정렬 (선택적)

    removed_files = []
    files_to_remove = set()

    # 연속적으로 이미지를 비교합니다.
    for i in range(len(files) - 1):
        file_path1 = os.path.join(folder_path, files[i])
        file_path2 = os.path.join(folder_path, files[i + 1])
        
        # SSIM 값 계산
        similarity = compute_image_ssim(file_path1, file_path2)
        if similarity > threshold:
            # 유사한 이미지가 발견된 경우
            if file_path2 not in files_to_remove:
                # print(f"files_to_remove add {file_path2}")
                files_to_remove.add(file_path2)

    # print(files_to_remove)
    # 파일을 한 번에 제거합니다.
    for file_path in files_to_remove:
        if os.path.exists(file_path):
            os.remove(file_path)

    print(f"Removing similar image: {folder_path} - ({len(files_to_remove)})")
    return list(files_to_remove)

dest_folder = 'D:/nsk/data/CH03_output'  # 대상 폴더 경로

# 배치별 폴더에서 중복 이미지 제거
for folder in os.listdir(dest_folder):
    batch_folder = os.path.join(dest_folder, folder)
    if os.path.isdir(batch_folder):
        print(f"Processing folder: {batch_folder}")
        find_and_remove_duplicates_in_folder(batch_folder)
# Out:
# Processing folder: D:/nsk/data/CH03_output\batch_1
# Removing similar image: D:/nsk/data/CH03_output\batch_1 - (188)
# Processing folder: D:/nsk/data/CH03_output\batch_10
# Removing similar image: D:/nsk/data/CH03_output\batch_10 - (411)
# Processing folder: D:/nsk/data/CH03_output\batch_100
# Removing similar image: D:/nsk/data/CH03_output\batch_100 - (457)
# Processing folder: D:/nsk/data/CH03_output\batch_101
# Removing similar image: D:/nsk/data/CH03_output\batch_101 - (462)
# Processing folder: D:/nsk/data/CH03_output\batch_102
# Removing similar image: D:/nsk/data/CH03_output\batch_102 - (510)
# Processing folder: D:/nsk/data/CH03_output\batch_103
# Removing similar image: D:/nsk/data/CH03_output\batch_103 - (448)
# Processing folder: D:/nsk/data/CH03_output\batch_104
# Removing similar image: D:/nsk/data/CH03_output\batch_104 - (453)
# Processing folder: D:/nsk/data/CH03_output\batch_105
# Removing similar image: D:/nsk/data/CH03_output\batch_105 - (441)
# Processing folder: D:/nsk/data/CH03_output\batch_106
# Removing similar image: D:/nsk/data/CH03_output\batch_106 - (639)
# Processing folder: D:/nsk/data/CH03_output\batch_107
# Removing similar image: D:/nsk/data/CH03_output\batch_107 - (573)
# Processing folder: D:/nsk/data/CH03_output\batch_108
# Removing similar image: D:/nsk/data/CH03_output\batch_108 - (422)
# Processing folder: D:/nsk/data/CH03_output\batch_109
# Removing similar image: D:/nsk/data/CH03_output\batch_109 - (420)
# Processing folder: D:/nsk/data/CH03_output\batch_11
# Removing similar image: D:/nsk/data/CH03_output\batch_11 - (427)
# Processing folder: D:/nsk/data/CH03_output\batch_110
# Removing similar image: D:/nsk/data/CH03_output\batch_110 - (424)
# Processing folder: D:/nsk/data/CH03_output\batch_111
# Removing similar image: D:/nsk/data/CH03_output\batch_111 - (409)
# Processing folder: D:/nsk/data/CH03_output\batch_112
# Removing similar image: D:/nsk/data/CH03_output\batch_112 - (420)
# Processing folder: D:/nsk/data/CH03_output\batch_113
# Removing similar image: D:/nsk/data/CH03_output\batch_113 - (430)
# Processing folder: D:/nsk/data/CH03_output\batch_114
# Removing similar image: D:/nsk/data/CH03_output\batch_114 - (431)
# Processing folder: D:/nsk/data/CH03_output\batch_115
# Removing similar image: D:/nsk/data/CH03_output\batch_115 - (93)
# Processing folder: D:/nsk/data/CH03_output\batch_12
# Removing similar image: D:/nsk/data/CH03_output\batch_12 - (452)
# Processing folder: D:/nsk/data/CH03_output\batch_13
# Removing similar image: D:/nsk/data/CH03_output\batch_13 - (664)
# Processing folder: D:/nsk/data/CH03_output\batch_14
# Removing similar image: D:/nsk/data/CH03_output\batch_14 - (658)
# Processing folder: D:/nsk/data/CH03_output\batch_15
# Removing similar image: D:/nsk/data/CH03_output\batch_15 - (701)
# Processing folder: D:/nsk/data/CH03_output\batch_16
# Removing similar image: D:/nsk/data/CH03_output\batch_16 - (688)
# Processing folder: D:/nsk/data/CH03_output\batch_17
# Removing similar image: D:/nsk/data/CH03_output\batch_17 - (665)
# Processing folder: D:/nsk/data/CH03_output\batch_18
# Removing similar image: D:/nsk/data/CH03_output\batch_18 - (689)
# Processing folder: D:/nsk/data/CH03_output\batch_19
# Removing similar image: D:/nsk/data/CH03_output\batch_19 - (680)
# Processing folder: D:/nsk/data/CH03_output\batch_2
# Removing similar image: D:/nsk/data/CH03_output\batch_2 - (462)
# Processing folder: D:/nsk/data/CH03_output\batch_20
# Removing similar image: D:/nsk/data/CH03_output\batch_20 - (664)
# Processing folder: D:/nsk/data/CH03_output\batch_21
# Removing similar image: D:/nsk/data/CH03_output\batch_21 - (650)
# Processing folder: D:/nsk/data/CH03_output\batch_22
# Removing similar image: D:/nsk/data/CH03_output\batch_22 - (659)
# Processing folder: D:/nsk/data/CH03_output\batch_23
# Removing similar image: D:/nsk/data/CH03_output\batch_23 - (682)
# Processing folder: D:/nsk/data/CH03_output\batch_24
# Removing similar image: D:/nsk/data/CH03_output\batch_24 - (662)
# Processing folder: D:/nsk/data/CH03_output\batch_25
# Removing similar image: D:/nsk/data/CH03_output\batch_25 - (681)
# Processing folder: D:/nsk/data/CH03_output\batch_26
# Removing similar image: D:/nsk/data/CH03_output\batch_26 - (660)
# Processing folder: D:/nsk/data/CH03_output\batch_27
# Removing similar image: D:/nsk/data/CH03_output\batch_27 - (689)
# Processing folder: D:/nsk/data/CH03_output\batch_28
# Removing similar image: D:/nsk/data/CH03_output\batch_28 - (691)
# Processing folder: D:/nsk/data/CH03_output\batch_29
# Removing similar image: D:/nsk/data/CH03_output\batch_29 - (658)
# Processing folder: D:/nsk/data/CH03_output\batch_3
# Removing similar image: D:/nsk/data/CH03_output\batch_3 - (607)
# Processing folder: D:/nsk/data/CH03_output\batch_30
# Removing similar image: D:/nsk/data/CH03_output\batch_30 - (681)
# Processing folder: D:/nsk/data/CH03_output\batch_31
# Removing similar image: D:/nsk/data/CH03_output\batch_31 - (694)
# Processing folder: D:/nsk/data/CH03_output\batch_32
# Removing similar image: D:/nsk/data/CH03_output\batch_32 - (661)
# Processing folder: D:/nsk/data/CH03_output\batch_33
# Removing similar image: D:/nsk/data/CH03_output\batch_33 - (677)
# Processing folder: D:/nsk/data/CH03_output\batch_34
# Removing similar image: D:/nsk/data/CH03_output\batch_34 - (687)
# Processing folder: D:/nsk/data/CH03_output\batch_35
# Removing similar image: D:/nsk/data/CH03_output\batch_35 - (641)
# Processing folder: D:/nsk/data/CH03_output\batch_36
# Removing similar image: D:/nsk/data/CH03_output\batch_36 - (655)
# Processing folder: D:/nsk/data/CH03_output\batch_37
# Removing similar image: D:/nsk/data/CH03_output\batch_37 - (432)
# Processing folder: D:/nsk/data/CH03_output\batch_38
# Removing similar image: D:/nsk/data/CH03_output\batch_38 - (406)
# Processing folder: D:/nsk/data/CH03_output\batch_39
# Removing similar image: D:/nsk/data/CH03_output\batch_39 - (500)
# Processing folder: D:/nsk/data/CH03_output\batch_4
# Removing similar image: D:/nsk/data/CH03_output\batch_4 - (417)
# Processing folder: D:/nsk/data/CH03_output\batch_40
# Removing similar image: D:/nsk/data/CH03_output\batch_40 - (401)
# Processing folder: D:/nsk/data/CH03_output\batch_41
# Removing similar image: D:/nsk/data/CH03_output\batch_41 - (486)
# Processing folder: D:/nsk/data/CH03_output\batch_42
# Removing similar image: D:/nsk/data/CH03_output\batch_42 - (456)
# Processing folder: D:/nsk/data/CH03_output\batch_43
# Removing similar image: D:/nsk/data/CH03_output\batch_43 - (440)
# Processing folder: D:/nsk/data/CH03_output\batch_44
# Removing similar image: D:/nsk/data/CH03_output\batch_44 - (421)
# Processing folder: D:/nsk/data/CH03_output\batch_45
# Removing similar image: D:/nsk/data/CH03_output\batch_45 - (447)
# Processing folder: D:/nsk/data/CH03_output\batch_46
# Removing similar image: D:/nsk/data/CH03_output\batch_46 - (472)
# Processing folder: D:/nsk/data/CH03_output\batch_47
# Removing similar image: D:/nsk/data/CH03_output\batch_47 - (478)
# Processing folder: D:/nsk/data/CH03_output\batch_48
# Removing similar image: D:/nsk/data/CH03_output\batch_48 - (497)
# Processing folder: D:/nsk/data/CH03_output\batch_49
# Removing similar image: D:/nsk/data/CH03_output\batch_49 - (465)
# Processing folder: D:/nsk/data/CH03_output\batch_5
# Removing similar image: D:/nsk/data/CH03_output\batch_5 - (399)
# Processing folder: D:/nsk/data/CH03_output\batch_50
# Removing similar image: D:/nsk/data/CH03_output\batch_50 - (439)
# Processing folder: D:/nsk/data/CH03_output\batch_51
# Removing similar image: D:/nsk/data/CH03_output\batch_51 - (469)
# Processing folder: D:/nsk/data/CH03_output\batch_52
# Removing similar image: D:/nsk/data/CH03_output\batch_52 - (458)
# Processing folder: D:/nsk/data/CH03_output\batch_53
# Removing similar image: D:/nsk/data/CH03_output\batch_53 - (405)
# Processing folder: D:/nsk/data/CH03_output\batch_54
# Removing similar image: D:/nsk/data/CH03_output\batch_54 - (438)
# Processing folder: D:/nsk/data/CH03_output\batch_55
# Removing similar image: D:/nsk/data/CH03_output\batch_55 - (435)
# Processing folder: D:/nsk/data/CH03_output\batch_56
# Removing similar image: D:/nsk/data/CH03_output\batch_56 - (421)
# Processing folder: D:/nsk/data/CH03_output\batch_57
# Removing similar image: D:/nsk/data/CH03_output\batch_57 - (463)
# Processing folder: D:/nsk/data/CH03_output\batch_58
# Removing similar image: D:/nsk/data/CH03_output\batch_58 - (399)
# Processing folder: D:/nsk/data/CH03_output\batch_59
# Removing similar image: D:/nsk/data/CH03_output\batch_59 - (409)
# Processing folder: D:/nsk/data/CH03_output\batch_6
# Removing similar image: D:/nsk/data/CH03_output\batch_6 - (500)
# Processing folder: D:/nsk/data/CH03_output\batch_60
# Removing similar image: D:/nsk/data/CH03_output\batch_60 - (415)
# Processing folder: D:/nsk/data/CH03_output\batch_61
# Removing similar image: D:/nsk/data/CH03_output\batch_61 - (553)
# Processing folder: D:/nsk/data/CH03_output\batch_62
# Removing similar image: D:/nsk/data/CH03_output\batch_62 - (436)
# Processing folder: D:/nsk/data/CH03_output\batch_63
# Removing similar image: D:/nsk/data/CH03_output\batch_63 - (477)
# Processing folder: D:/nsk/data/CH03_output\batch_64
# Removing similar image: D:/nsk/data/CH03_output\batch_64 - (433)
# Processing folder: D:/nsk/data/CH03_output\batch_65
# Removing similar image: D:/nsk/data/CH03_output\batch_65 - (426)
# Processing folder: D:/nsk/data/CH03_output\batch_66
# Removing similar image: D:/nsk/data/CH03_output\batch_66 - (468)
# Processing folder: D:/nsk/data/CH03_output\batch_67
# Removing similar image: D:/nsk/data/CH03_output\batch_67 - (504)
# Processing folder: D:/nsk/data/CH03_output\batch_68
# Removing similar image: D:/nsk/data/CH03_output\batch_68 - (464)
# Processing folder: D:/nsk/data/CH03_output\batch_69
# Removing similar image: D:/nsk/data/CH03_output\batch_69 - (468)
# Processing folder: D:/nsk/data/CH03_output\batch_7
# Removing similar image: D:/nsk/data/CH03_output\batch_7 - (385)
# Processing folder: D:/nsk/data/CH03_output\batch_70
# Removing similar image: D:/nsk/data/CH03_output\batch_70 - (444)
# Processing folder: D:/nsk/data/CH03_output\batch_71
# Removing similar image: D:/nsk/data/CH03_output\batch_71 - (453)
# Processing folder: D:/nsk/data/CH03_output\batch_72
# Removing similar image: D:/nsk/data/CH03_output\batch_72 - (458)
# Processing folder: D:/nsk/data/CH03_output\batch_73
# Removing similar image: D:/nsk/data/CH03_output\batch_73 - (420)
# Processing folder: D:/nsk/data/CH03_output\batch_74
# Removing similar image: D:/nsk/data/CH03_output\batch_74 - (451)
# Processing folder: D:/nsk/data/CH03_output\batch_75
# Removing similar image: D:/nsk/data/CH03_output\batch_75 - (453)
# Processing folder: D:/nsk/data/CH03_output\batch_76
# Removing similar image: D:/nsk/data/CH03_output\batch_76 - (422)
# Processing folder: D:/nsk/data/CH03_output\batch_77
# Removing similar image: D:/nsk/data/CH03_output\batch_77 - (444)
# Processing folder: D:/nsk/data/CH03_output\batch_78
# Removing similar image: D:/nsk/data/CH03_output\batch_78 - (467)
# Processing folder: D:/nsk/data/CH03_output\batch_79
# Removing similar image: D:/nsk/data/CH03_output\batch_79 - (427)
# Processing folder: D:/nsk/data/CH03_output\batch_8
# Removing similar image: D:/nsk/data/CH03_output\batch_8 - (463)
# Processing folder: D:/nsk/data/CH03_output\batch_80
# Removing similar image: D:/nsk/data/CH03_output\batch_80 - (430)
# Processing folder: D:/nsk/data/CH03_output\batch_81
# Removing similar image: D:/nsk/data/CH03_output\batch_81 - (496)
# Processing folder: D:/nsk/data/CH03_output\batch_82
# Removing similar image: D:/nsk/data/CH03_output\batch_82 - (417)
# Processing folder: D:/nsk/data/CH03_output\batch_83
# Removing similar image: D:/nsk/data/CH03_output\batch_83 - (415)
# Processing folder: D:/nsk/data/CH03_output\batch_84
# Removing similar image: D:/nsk/data/CH03_output\batch_84 - (413)
# Processing folder: D:/nsk/data/CH03_output\batch_85
# Removing similar image: D:/nsk/data/CH03_output\batch_85 - (418)
# Processing folder: D:/nsk/data/CH03_output\batch_86
# Removing similar image: D:/nsk/data/CH03_output\batch_86 - (431)
# Processing folder: D:/nsk/data/CH03_output\batch_87
# Removing similar image: D:/nsk/data/CH03_output\batch_87 - (462)
# Processing folder: D:/nsk/data/CH03_output\batch_88
# Removing similar image: D:/nsk/data/CH03_output\batch_88 - (473)
# Processing folder: D:/nsk/data/CH03_output\batch_89
# Removing similar image: D:/nsk/data/CH03_output\batch_89 - (429)
# Processing folder: D:/nsk/data/CH03_output\batch_9
# Removing similar image: D:/nsk/data/CH03_output\batch_9 - (471)
# Processing folder: D:/nsk/data/CH03_output\batch_90
# Removing similar image: D:/nsk/data/CH03_output\batch_90 - (480)
# Processing folder: D:/nsk/data/CH03_output\batch_91
# Removing similar image: D:/nsk/data/CH03_output\batch_91 - (473)
# Processing folder: D:/nsk/data/CH03_output\batch_92
# Removing similar image: D:/nsk/data/CH03_output\batch_92 - (475)
# Processing folder: D:/nsk/data/CH03_output\batch_93
# Removing similar image: D:/nsk/data/CH03_output\batch_93 - (463)
# Processing folder: D:/nsk/data/CH03_output\batch_94
# Removing similar image: D:/nsk/data/CH03_output\batch_94 - (460)
# Processing folder: D:/nsk/data/CH03_output\batch_95
# Removing similar image: D:/nsk/data/CH03_output\batch_95 - (463)
# Processing folder: D:/nsk/data/CH03_output\batch_96
# Removing similar image: D:/nsk/data/CH03_output\batch_96 - (356)
# Processing folder: D:/nsk/data/CH03_output\batch_97
# Removing similar image: D:/nsk/data/CH03_output\batch_97 - (452)
# Processing folder: D:/nsk/data/CH03_output\batch_98
# Removing similar image: D:/nsk/data/CH03_output\batch_98 - (470)
# Processing folder: D:/nsk/data/CH03_output\batch_99
# Removing similar image: D:/nsk/data/CH03_output\batch_99 - (464)
